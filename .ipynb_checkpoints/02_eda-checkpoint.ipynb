# %%
# Data manipulation imports
import pandas as pd

# Plotting imports
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
gov = pd.read_csv('gov.csv')
gov.head()
# Out:
#          country   population  area_square_km  density_square_km  \
# 0          China  1444216.107         9706961           148.7815
# 1          India  1393409.038         3287590           423.8391
# 2  United States   332915.073         9372610            35.5200
# 3      Indonesia   276361.783         1904569           145.1046
# 4       Pakistan   225199.937          881912           255.3542
#
#    average_years_of_school  auto_demo_polity  gdp_per_capita  happiness_index  \
# 0                     2.77              -7.0      12009.4430            5.140
# 1                     1.24               9.0       5722.5186            4.565
# 2                    10.61              10.0      53533.2810            7.119
# 3                     2.26               9.0       9781.2070            5.399
# 4                     1.31               7.0       4815.9243            5.194
#
#    freedom_index  less_corruption_index  life_expectancy_years  \
# 0        0.51697                0.02781                 75.928
# 1        0.39786                0.08492                 68.607
# 2        0.54604                0.15890                 78.910
# 3        0.46611                0.00000                 70.768
# 4        0.12102                0.10464                 66.577
#
#    inequality_gini  median_household_income_dollars  \
# 0             38.5                           6180.0
# 1             35.7                           3168.0
# 2             41.1                          43585.0
# 3             37.8                           2199.0
# 4             33.5                           4060.0
#
#    median_per_capita_income_dollars  median_individual_income_dollars
# 0                            1786.0                           10410.0
# 1                             616.0                            2130.0
# 2                           15480.0                           65760.0
# 3                             541.0                            4050.0
# 4                             480.0                            1530.0

# %% [markdown]
# ## EDA
# Look for trends in the data before modeling - ****please note that corruption is measured as it pertains to happiness, so the higher the corruption value is the _less_ corrupt the country is because citizens rate happiness higher (per index)****

# %%
plt.figure(figsize = (3, 15))

ax = plt.axes()
ax.set_title('Feature Correlation to Corruption')
corr = gov.corr()[['less_corruption_index']]
sns.set(font_scale = 2)
sns.heatmap(corr.sort_values(by = 'less_corruption_index', ascending = True), 
            annot = True, cmap = 'mako', vmin = -1, vmax = 1, linecolor = 'black', 
            linewidth = 1, annot_kws = {'fontsize' : 16});

# %%
corr = gov.corr()
mask = np.triu(np.ones_like(corr, dtype = bool))
plt.figure(figsize = (20, 10))
ax = plt.axes()
sns.set(font_scale = 1.2)
ax.set_facecolor('white')
sns.heatmap(corr, annot = True, cmap = "Greens", mask = mask, ax = ax)
ax.set_title('Feature Heatmap');

# %% [markdown]
# Explore relationships of all variables to corruption:

# %%
# Check population against less corruption
plt.figure(figsize = (15, 8))
g = sns.scatterplot(data = gov, x = 'population', y = 'less_corruption_index', color = '.2', marker = 'X') #credit to Seaborn documentation for X marker

plt.title('Population Against Less Corruption', size = 20)
plt.xlabel('Population', size = 16)
plt.ylabel('Less Corruption (Index)', size = 16)
g.set_xscale('log')

plt.tight_layout();

# %%
# Check area against less corruption
plt.figure(figsize = (15, 8))
g = sns.scatterplot(data = gov, x = 'area_square_km', y = 'less_corruption_index', color = '.2', marker = 'X')
plt.title('Geographical Area Against Less Corruption', size = 20)
plt.xlabel('Area (Square Kilometers)', size = 16)
plt.ylabel('Less Corruption (Index)', size = 16)
g.set_xscale('log')

plt.tight_layout();

# %%
# Check density against less corruption
plt.figure(figsize = (15, 8))
g = sns.scatterplot(data = gov, x = 'density_square_km', y = 'less_corruption_index', color = '.2', marker = 'X')

plt.title('Geographical Density Against Less Corruption', size = 20)
plt.xlabel('Density (Square Kilometers)', size = 16)
plt.ylabel('Less Corruption (Index)', size = 16)
g.set_xscale('log')

plt.tight_layout();

# %%
# Check average years in school against less corruption
plt.figure(figsize = (15, 8))
sns.regplot(data = gov, x = 'average_years_of_school', y = 'less_corruption_index', scatter_kws = {'color': 'black'},
            line_kws = {'color': 'red'}, ci = None)

plt.title('Average Years In School Against Less Corruption', size = 20)
plt.xlabel('Average Amount Of Time In School (Years)', size = 16)
plt.ylabel('Less Corruption (Index)', size = 16)

plt.tight_layout();

# %%
# Check decentralized form of government against less corruption
plt.figure(figsize = (15, 8))
sns.regplot(data = gov, x = 'auto_demo_polity', y = 'less_corruption_index', scatter_kws = {'color': 'black'},
            line_kws = {'color': 'red'}, ci = None)

plt.title('Decentralized Form Of Government Against Less Corruption', size = 20)
plt.xlabel('Auto Demo Polity (Index)', size = 16)
plt.ylabel('Less Corruption (Index)', size = 16)

plt.tight_layout();

# %%
# Check gdp against less corruption
plt.figure(figsize = (15, 8))
g = sns.scatterplot(data = gov, x = 'gdp_per_capita', y = 'less_corruption_index', color = '.2', marker = 'X') 

plt.title('GDP Per Capita Against Less Corruption', size = 20)
plt.xlabel('GDP (Dollars adjusted for price differences between countries)', size = 16)
plt.ylabel('Less Corruption (Index)', size = 16)

plt.tight_layout();

# %%
# Check happiness against less corruption
plt.figure(figsize = (15, 8))
g = sns.scatterplot(data = gov, x = 'happiness_index', y = 'less_corruption_index', color = '.2', marker = 'X') 

plt.title('Happiness Index Against Less Corruption', size = 20)
plt.xlabel('Happiness (Index)', size = 16)
plt.ylabel('Less Corruption (Index)', size = 16)

plt.tight_layout();

# %%
# Check freedom against less corruption
plt.figure(figsize = (15, 8))
g = sns.scatterplot(data = gov, x = 'freedom_index', y = 'less_corruption_index', color = '.2', marker = 'X') 

plt.title('Freedom Index Against Less Corruption', size = 20)
plt.xlabel('Freedom (Index)', size = 16)
plt.ylabel('Less Corruption (Index)', size = 16)

plt.tight_layout();

# %%
# Check life expectancy against less corruption
plt.figure(figsize = (15, 8))
g = sns.scatterplot(data = gov, x = 'life_expectancy_years', y = 'less_corruption_index', color = '.2', marker = 'X') #credit to Seaborn documenta

plt.title('Life Expectancy Against Less Corruption', size = 20)
plt.xlabel('Life Expectancy (Years)', size = 16)
plt.ylabel('Less Corruption (Index)', size = 16)

plt.tight_layout();

# %%
# Check inequality against less corruption
plt.figure(figsize = (15, 8))
sns.regplot(data = gov, x = 'inequality_gini', y = 'less_corruption_index', scatter_kws = {'color': 'black'},
            line_kws = {'color': 'red'}, ci = None)


plt.title('Inequality Against Less Corruption', size = 20)
plt.xlabel('Inequality (Gini)', size = 16)
plt.ylabel('Less Corruption (Index)', size = 16)

plt.tight_layout();

# %%
# Check median household income against less corruption
plt.figure(figsize = (15, 8))
g = sns.scatterplot(data = gov, x = 'median_household_income_dollars', y = 'less_corruption_index', color = '.2', marker = 'X') #credit to Seaborn documenta

plt.title('Median Household Income Against Less Corruption', size = 20)
plt.xlabel('Median Household Income (Dollars)', size = 16)
plt.ylabel('Less Corruption (Index)', size = 16)
g.set_xscale('log')

plt.tight_layout();

# %%
# Check median per capita income against less corruption
plt.figure(figsize = (15, 8))
g = sns.scatterplot(data = gov, x = 'median_per_capita_income_dollars', y = 'less_corruption_index', color = '.2', marker = 'X') #credit to Seaborn documenta

plt.title('Median Per Capita Income Against Less Corruption', size = 20)
plt.xlabel('Median Per Capita Income (Dollars)', size = 16)
plt.ylabel('Less Corruption (Index)', size = 16)
g.set_xscale('log')

plt.tight_layout();

# %%
# Check median individual income dollars against less corruption
plt.figure(figsize = (15, 8))
g = sns.scatterplot(data = gov, x = 'median_individual_income_dollars', y = 'less_corruption_index', color = '.2', marker = 'X') #credit to Seaborn documenta

plt.title('Median Individual Income Against Less Corruption', size = 20)
plt.xlabel('Median Per Capita Income (Dollars)', size = 16)
plt.ylabel('Less Corruption (Index)', size = 16)
g.set_xscale('log')

plt.tight_layout();

# %% [markdown]
# Check some correlations against happiness:

# %%
# Check population against happiness
plt.figure(figsize = (15, 8))
g = sns.regplot(data = gov, x = 'population', y = 'happiness_index', scatter_kws = {'color': 'black'},
            line_kws = {'color': 'red'}, ci = None)

plt.title('Population Against Happiness', size = 20)
plt.xlabel('Population (People)', size = 16)
plt.ylabel('Happiness (Index)', size = 16)

plt.tight_layout();

# %%
# Check average years in school against less corruption
plt.figure(figsize = (15, 8))
g = sns.scatterplot(data = gov, x = 'average_years_of_school', y = 'happiness_index', color = '.2', marker = 'X')

plt.title('Aveage Years In School Against Happiness', size = 20)
plt.xlabel('Average Amount Of Time In School (Years)', size = 16)
plt.ylabel('Happiness Score', size = 16)

plt.tight_layout();

# %%
# Check life expectancy against happiness
plt.figure(figsize = (15, 8))
g = sns.scatterplot(data = gov, x = 'average_years_of_school', y = 'happiness_index', color = '.2', marker = 'X')
plt.title('Life Expectancy Against Happiness', size = 20)
plt.xlabel('Life Expectancy (Years)', size = 16)
plt.ylabel('Happiness (Index)', size = 16)

plt.tight_layout();

# %%
# Check decentralized gov against happiness
plt.figure(figsize = (15, 8))
sns.regplot(data = gov, x = 'auto_demo_polity', y = 'happiness_index', scatter_kws = {'color': 'black'},
            line_kws = {'color': 'red'}, ci = None)

plt.title('Decentralized Government Against Happiness', size = 20)
plt.xlabel('Decentralized Government Score (Index)', size = 16)
plt.ylabel('Happiness (Index)', size = 16)

plt.tight_layout();

# %%
gov.sort_values(by = 'auto_demo_polity', ascending = True).head(10)
# Out:
#                   country   population  area_square_km  density_square_km  \
# 113                 Qatar     2930.528           11586           252.9370
# 37           Saudi Arabia    35340.683         2149690            16.4399
# 77   United Arab Emirates     9991.089           83600           119.5106
# 0                   China  1444216.107         9706961           148.7815
# 16                   Iran    85028.759         1648195            51.5890
# 88                   Laos     7379.358          236800            31.1628
# 14                Vietnam    98168.833          331212           296.3927
# 80                Belarus     9442.862          207600            45.4858
# 73             Azerbaijan    10223.342           86600           118.0524
# 55             Kazakhstan    18994.962         2724900             6.9709
#
#      average_years_of_school  auto_demo_polity  gdp_per_capita  \
# 113                     3.26             -10.0      98941.2030
# 37                      3.19             -10.0      41863.2110
# 77                      2.39              -8.0      67469.6480
# 0                       2.77              -7.0      12009.4430
# 16                      1.17              -7.0      14834.1780
# 88                      1.40              -7.0       5854.8647
# 14                      3.00              -7.0       5462.5864
# 80                      3.38              -7.0      16681.6520
# 73                      3.38              -7.0      14372.9700
# 55                      4.46              -6.0      21445.6930
#
#      happiness_index  freedom_index  less_corruption_index  \
# 113            6.611        0.64040                0.52208
# 37             6.411        0.31048                0.32524
# 77             6.901        0.64157                0.38583
# 0              5.140        0.51697                0.02781
# 16             4.686        0.30033                0.05863
# 88             4.876        0.59591                0.24249
# 14             5.360        0.59444                0.10441
# 80             5.813        0.37938                0.19090
# 73             5.212        0.37030                0.16065
# 55             5.855        0.51649                0.08454
#
#      life_expectancy_years  inequality_gini  median_household_income_dollars  \
# 113                 79.758             41.1                          26555.0
# 37                  74.651             45.9                          24980.0
# 77                  77.285             32.5                           7437.5
# 0                   75.928             38.5                           6180.0
# 16                  75.796             40.8                          12046.0
# 88                  66.546             36.4                           3379.0
# 14                  75.110             35.7                           4783.0
# 80                  73.652             25.2                          15085.0
# 73                  72.266             33.7                          11446.0
# 55                  71.319             27.5                           7492.0
#
#      median_per_capita_income_dollars  median_individual_income_dollars
# 113                            5117.0                           11480.0
# 37                             4762.0                           22850.0
# 77                             1790.5                           43470.0
# 0                              1786.0                           10410.0
# 16                             3115.0                            5420.0
# 88                              615.0                            2570.0
# 14                             1124.0                            2540.0
# 80                             5236.0                            6280.0
# 73                             2430.0                           11480.0
# 55                             1958.0                           11480.0

# %%
gov_no_oil = gov[gov['auto_demo_polity'] > -8] #most of the strongest autocracies are oil countries which could skew findings as few countries have that many resources
gov_no_oil.head()
# Out:
#          country   population  area_square_km  density_square_km  \
# 0          China  1444216.107         9706961           148.7815
# 1          India  1393409.038         3287590           423.8391
# 2  United States   332915.073         9372610            35.5200
# 3      Indonesia   276361.783         1904569           145.1046
# 4       Pakistan   225199.937          881912           255.3542
#
#    average_years_of_school  auto_demo_polity  gdp_per_capita  happiness_index  \
# 0                     2.77              -7.0      12009.4430            5.140
# 1                     1.24               9.0       5722.5186            4.565
# 2                    10.61              10.0      53533.2810            7.119
# 3                     2.26               9.0       9781.2070            5.399
# 4                     1.31               7.0       4815.9243            5.194
#
#    freedom_index  less_corruption_index  life_expectancy_years  \
# 0        0.51697                0.02781                 75.928
# 1        0.39786                0.08492                 68.607
# 2        0.54604                0.15890                 78.910
# 3        0.46611                0.00000                 70.768
# 4        0.12102                0.10464                 66.577
#
#    inequality_gini  median_household_income_dollars  \
# 0             38.5                           6180.0
# 1             35.7                           3168.0
# 2             41.1                          43585.0
# 3             37.8                           2199.0
# 4             33.5                           4060.0
#
#    median_per_capita_income_dollars  median_individual_income_dollars
# 0                            1786.0                           10410.0
# 1                             616.0                            2130.0
# 2                           15480.0                           65760.0
# 3                             541.0                            4050.0
# 4                             480.0                            1530.0

# %%
# Check decentralized gov against happiness
plt.figure(figsize = (15, 8))
sns.regplot(data = gov_no_oil, x = 'auto_demo_polity', y = 'less_corruption_index', scatter_kws = {'color': 'black'},
            line_kws = {'color': 'red'}, ci = None)

plt.title('Decentralized Government To Less Corruption (Without High GDP Autocratic Countries)', size = 20)
plt.xlabel('Decentralized Government Score (Index)', size = 16)
plt.ylabel('Less Corruption (Index)', size = 16)

plt.tight_layout();

# %%
plt.figure(figsize = (3, 15))
ax = plt.axes()
ax.set_title('Feature Correlation to Decentralization')
corr = gov.corr()[['auto_demo_polity']]
sns.set(font_scale = 2)
sns.heatmap(corr.sort_values(by = 'auto_demo_polity', ascending = True), 
            annot = True, cmap = 'mako', vmin = -1, vmax = 1, linecolor = 'black', 
            linewidth = 1, annot_kws = {'fontsize' : 16});

# %%
# Finally, look for values for Switzerland as a case study
gov[gov['country'] == 'Switzerland']
# Out:
#         country  population  area_square_km  density_square_km  \
# 83  Switzerland    8715.494           41284           211.1107
#
#     average_years_of_school  auto_demo_polity  gdp_per_capita  \
# 83                     9.76              10.0        62835.66
#
#     happiness_index  freedom_index  less_corruption_index  \
# 83            7.587        0.66557                0.41978
#
#     life_expectancy_years  inequality_gini  median_household_income_dollars  \
# 83                 83.142             32.7                           7437.5
#
#     median_per_capita_income_dollars  median_individual_income_dollars
# 83                            1790.5                           85500.0

# %%
# Data manipulation imports
import pandas as pd
import numpy as np

# Graphing imports
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read in data from datasets folder
df_demographics = pd.read_csv('datasets/demographics_by_country.csv')
df_education = pd.read_csv('datasets/education_by_country.csv')
df_gdp = pd.read_csv('datasets/gdp_by_country.csv')
df_happiness = pd.read_csv('datasets/happiness_by_country.csv')
df_life_expectancy = pd.read_csv('datasets/life_expectancy_by_country.csv')
df_inequality = pd.read_csv('datasets/inequality_by_country_gini_data.csv')
df_income = pd.read_csv('datasets/median_income_by_country_data.csv')

# %%
df_demographics.head()
# Out:
#   cca2           name      pop2021      pop2020      pop2050      pop2030  \
# 0   CN          China  1444216.107  1439323.776  1402405.170  1464340.159
# 1   IN          India  1393409.038  1380004.385  1639176.033  1503642.322
# 2   US  United States   332915.073   331002.651   379419.102   349641.876
# 3   ID      Indonesia   276361.783   273523.615   330904.664   299198.430
# 4   PK       Pakistan   225199.937   220892.340   338013.196   262958.794
#
#        pop2019      pop2015      pop2010      pop2000      pop1990  \
# 0  1433783.686  1406847.870  1368810.615  1290550.765  1176883.674
# 1  1366417.754  1310152.403  1234281.170  1056575.549   873277.798
# 2   329064.917   320878.310   309011.475   281710.909   252120.309
# 3   270625.568   258383.256   241834.215   211513.823   181413.402
# 4   216565.318   199426.964   179424.641   142343.578   107647.921
#
#        pop1980     pop1970     area   Density  GrowthRate  WorldPercentage  \
# 0  1000089.235  827601.394  9706961  148.7815      1.0034           0.1834
# 1   698952.844  555189.792  3287590  423.8391      1.0097           0.1769
# 2   229476.354  209513.341  9372610   35.5200      1.0058           0.0423
# 3   147447.836  114793.178  1904569  145.1046      1.0104           0.0351
# 4    78054.343   58142.060   881912  255.3542      1.0195           0.0286
#
#    rank
# 0     1
# 1     2
# 2     3
# 3     4
# 4     5

# %%
df_demographics = df_demographics.rename(columns = {'name' : 'country',
                                                    'pop2021' :'population',
                                                    'area' : 'area_square_km',
                                                    'Density' : 'density_square_km'})

df_demographics = df_demographics[['country', 'population', 'area_square_km','density_square_km']]
df_demographics.head()
# Out:
#          country   population  area_square_km  density_square_km
# 0          China  1444216.107         9706961           148.7815
# 1          India  1393409.038         3287590           423.8391
# 2  United States   332915.073         9372610            35.5200
# 3      Indonesia   276361.783         1904569           145.1046
# 4       Pakistan   225199.937          881912           255.3542

# %%
df_education.head()
# Out:
#         Entity      Code    Year  \
# 0     Abkhazia  OWID_ABK  2015.0
# 1  Afghanistan       AFG  1816.0
# 2  Afghanistan       AFG  1817.0
# 3  Afghanistan       AFG  1818.0
# 4  Afghanistan       AFG  1819.0
#
#    Political Regime (OWID based on Polity IV and Wimmer & Min)  \
# 0                                                NaN
# 1                                               -6.0
# 2                                               -6.0
# 3                                               -6.0
# 4                                               -6.0
#
#    Average Total Years of Schooling for Adult Population (Lee-Lee (2016), Barro-Lee (2018) and UNDP (2018))  \
# 0                                                NaN
# 1                                               0.35
# 2                                               0.35
# 3                                               0.35
# 4                                               0.35
#
#    Year.1  Total population (Gapminder, HYDE & UN) Continent
# 0     NaN                                      NaN      Asia
# 1  1970.0                                3296506.0       NaN
# 2  1970.0                                3302044.0       NaN
# 3  1970.0                                3308390.0       NaN
# 4  1970.0                                3315547.0       NaN

# %%
df_education = df_education[df_education['Year'] == 2015]

df_education = df_education.rename(columns = {'Entity' : 'country',
                                              'Political Regime (OWID based on Polity IV and Wimmer & Min)' :'auto_demo_polity',
                                              'Average Total Years of Schooling for Adult Population (Lee-Lee (2016), Barro-Lee (2018) and UNDP (2018))' : 'average_years_of_school'})

df_education = df_education[['country', 'average_years_of_school', 'auto_demo_polity']]
df_education.head()
# Out:
#                    country  average_years_of_school  auto_demo_polity
# 0                 Abkhazia                      NaN               NaN
# 177            Afghanistan                     0.35              -1.0
# 338                 Africa                      NaN               NaN
# 343  Akrotiri and Dhekelia                      NaN               NaN
# 542                Albania                     3.31               9.0

# %%
df_gdp.head()
# Out:
#         Entity      Code  Year  \
# 0     Abkhazia  OWID_ABK  2015
# 1  Afghanistan       AFG  1816
# 2  Afghanistan       AFG  1817
# 3  Afghanistan       AFG  1818
# 4  Afghanistan       AFG  1819
#
#    Output-side real GDP per capita (gdppc_o) (PWT 9.1 (2019))  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Political Regime (OWID based on Polity IV and Wimmer & Min)  \
# 0                                                NaN
# 1                                               -6.0
# 2                                               -6.0
# 3                                               -6.0
# 4                                               -6.0
#
#    Total population (Gapminder, HYDE & UN) Continent
# 0                                      NaN      Asia
# 1                                3296506.0       NaN
# 2                                3302044.0       NaN
# 3                                3308390.0       NaN
# 4                                3315547.0       NaN

# %%
df_gdp = df_gdp[df_gdp['Year'] == 2015]

df_gdp = df_gdp.rename(columns = {'Entity' : 'country',
                                  'Output-side real GDP per capita (gdppc_o) (PWT 9.1 (2019))' :  'gdp_per_capita'})

df_gdp = df_gdp[['country', 'gdp_per_capita']]
df_gdp.head()
# Out:
#                    country  gdp_per_capita
# 0                 Abkhazia             NaN
# 177            Afghanistan             NaN
# 338                 Africa             NaN
# 343  Akrotiri and Dhekelia             NaN
# 389                Albania       11228.951

# %% [markdown]
# Only keep the 'Output-side real GDP per capita (gdppc_o) (PWT 9.1 (2019))' column for 2015 data, transfer to snake-case

# %%
# Some of the data is already standard-scaled
df_happiness.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204
# 3     0.34699            2.46531
# 4     0.45811            2.45176

# %% [markdown]
# Only keep the 'Happiness_Score' column, transfer to snake-case

# %%
df_happiness = df_happiness.rename(columns = {'Country' : 'country',
                                              'Happiness Score' : 'happiness_index',
                                              'Freedom' : 'freedom_index',
                                              'Trust (Government Corruption)' : 'less_corruption_index'})

df_happiness = df_happiness[['country', 'happiness_index', 'freedom_index', 'less_corruption_index']]
df_happiness.head()
# Out:
#        country  happiness_index  freedom_index  less_corruption_index
# 0  Switzerland            7.587        0.66557                0.41978
# 1      Iceland            7.561        0.62877                0.14145
# 2      Denmark            7.527        0.64938                0.48357
# 3       Norway            7.522        0.66973                0.36503
# 4       Canada            7.427        0.63297                0.32957

# %%
df_life_expectancy.head()
# Out:
#         Entity Code  Year  Life expectancy
# 0  Afghanistan  AFG  1950           27.638
# 1  Afghanistan  AFG  1951           27.878
# 2  Afghanistan  AFG  1952           28.361
# 3  Afghanistan  AFG  1953           28.852
# 4  Afghanistan  AFG  1954           29.350

# %% [markdown]
# Only keep the 'Life expectancy' column for 2015 data, transfer to snake-case

# %%
df_life_expectancy = df_life_expectancy[df_life_expectancy['Year'] == 2015]

df_life_expectancy = df_life_expectancy.rename(columns = {'Entity' : 'country',
                                                          'Life expectancy' :  'life_expectancy_years'})

df_life_expectancy = df_life_expectancy[['country', 'life_expectancy_years']]
df_life_expectancy.head()
# Out:
#             country  life_expectancy_years
# 65      Afghanistan                 63.377
# 137          Africa                 61.607
# 207         Albania                 78.025
# 280         Algeria                 76.090
# 350  American Samoa                 73.588

# %%
df_inequality.head()
# Out:
#                     name                   slug  value date_of_information  \
# 0           South Africa           south-africa   63.0           2014 est.
# 1                Namibia                namibia   59.1           2015 est.
# 2                 Zambia                 zambia   57.1           2015 est.
# 3  Sao Tome and Principe  sao-tome-and-principe   56.3           2017 est.
# 4               Eswatini               eswatini   54.6           2016 est.
#
#    ranking  region
# 0        1  Africa
# 1        2  Africa
# 2        3  Africa
# 3        4  Africa
# 4        5  Africa

# %%
df_inequality = df_inequality.rename(columns = {'name' : 'country',
                                                'value' :  'inequality_gini'})

df_inequality = df_inequality[['country', 'inequality_gini']]
df_inequality.head()
# Out:
#                  country  inequality_gini
# 0           South Africa             63.0
# 1                Namibia             59.1
# 2                 Zambia             57.1
# 3  Sao Tome and Principe             56.3
# 4               Eswatini             54.6

# %%
df_income.head()
# Out:
#       country  medianHouseholdIncome  medianPerCapitaIncome  \
# 0  Luxembourg                52493.0                18418.0
# 1      Norway                51489.0                19308.0
# 2      Sweden                50514.0                18632.0
# 3   Australia                46555.0                15026.0
# 4     Denmark                44360.0                18262.0
#
#    medianAnnualIncome    pop2021
# 0             73910.0    634.814
# 1             82500.0   5465.630
# 2             55840.0  10160.169
# 3             54910.0  25788.215
# 4             63240.0   5813.298

# %%
df_income = df_income.rename(columns = {'medianHouseholdIncome' : 'median_household_income_dollars',
                                        'medianPerCapitaIncome' :  'median_per_capita_income_dollars',
                                        'medianAnnualIncome' : 'median_individual_income_dollars'})

df_income = df_income[['country', 'median_household_income_dollars', 'median_per_capita_income_dollars', 'median_individual_income_dollars']]
df_income.head()
# Out:
#       country  median_household_income_dollars  \
# 0  Luxembourg                          52493.0
# 1      Norway                          51489.0
# 2      Sweden                          50514.0
# 3   Australia                          46555.0
# 4     Denmark                          44360.0
#
#    median_per_capita_income_dollars  median_individual_income_dollars
# 0                           18418.0                           73910.0
# 1                           19308.0                           82500.0
# 2                           18632.0                           55840.0
# 3                           15026.0                           54910.0
# 4                           18262.0                           63240.0

# %% [markdown]
# ## Merge Dataframes
# Merge all of the different datasets into one

# %%
gov = pd.merge(left = df_demographics, right = df_education, on = 'country')
gov = pd.merge(left = gov, right = df_gdp, on = 'country' )
gov = pd.merge(left = gov, right = df_happiness, on = 'country')
gov = pd.merge(left = gov, right = df_life_expectancy, on = 'country')
gov = pd.merge(left = gov, right = df_inequality, on = 'country' )
gov = pd.merge(left = gov, right = df_income, on = 'country')
gov.head(30)
# Out:
#            country   population  area_square_km  density_square_km  \
# 0            China  1444216.107         9706961           148.7815
# 1            India  1393409.038         3287590           423.8391
# 2    United States   332915.073         9372610            35.5200
# 3        Indonesia   276361.783         1904569           145.1046
# 4         Pakistan   225199.937          881912           255.3542
# 5           Brazil   213993.437         8515767            25.1291
# 6          Nigeria   211400.708          923768           228.8461
# 7       Bangladesh   166303.498          147570          1126.9465
# 8           Russia   145912.025        17098242             8.5337
# 9           Mexico   130262.216         1964375            66.3123
# 10           Japan   126050.804          377930           333.5295
# 11        Ethiopia   117876.227         1104300           106.7429
# 12     Philippines   111046.913          342353           324.3638
# 13           Egypt   104258.327         1002450           104.0035
# 14         Vietnam    98168.833          331212           296.3927
# 15          Turkey    85042.738          783562           108.5335
# 16            Iran    85028.759         1648195            51.5890
# 17         Germany    83900.473          357114           234.9403
# 18        Thailand    69950.850          513120           136.3245
# 19  United Kingdom    68207.116          242900           280.8033
# 20          France    65426.179          551695           118.5912
# 21        Tanzania    61498.437          945087            65.0717
# 22           Italy    60367.477          301336           200.3328
# 23    South Africa    60041.994         1221037            49.1730
# 24           Kenya    54985.698          580367            94.7430
# 25        Colombia    51265.844         1141748            44.9012
# 26          Uganda    47123.531          241550           195.0881
# 27           Spain    46745.216          505992            92.3833
# 28       Argentina    45605.826         2780400            16.4026
# 29           Sudan    44909.353         1886068            23.8111
#
#     average_years_of_school  auto_demo_polity  gdp_per_capita  \
# 0                      2.77              -7.0      12009.4430
# 1                      1.24               9.0       5722.5186
# 2                     10.61              10.0      53533.2810
# 3                      2.26               9.0       9781.2070
# 4                      1.31               7.0       4815.9243
# 5                      3.09               8.0      14272.8540
# 6                       NaN               7.0       4965.5610
# 7                      1.16               1.0       3114.0554
# 8                      5.26               4.0      22832.8630
# 9                      2.89               8.0      16903.8200
# 10                     7.08              10.0      38875.0660
# 11                      NaN               NaN       1615.0925
# 12                     4.03               8.0       6824.7671
# 13                     1.03              -4.0      10772.8500
# 14                     3.00              -7.0       5462.5864
# 15                     2.02               3.0      25508.6070
# 16                     1.17              -7.0      14834.1780
# 17                     7.71              10.0      44482.5080
# 18                     1.87              -3.0      14661.5210
# 19                     7.54              10.0      38172.3550
# 20                     4.96               9.0      37809.0630
# 21                     1.79               3.0       2533.8428
# 22                     5.17              10.0      35186.2540
# 23                     4.44               9.0      11924.6000
# 24                     1.45               9.0       2935.5334
# 25                     3.38               7.0      12521.3870
# 26                     1.05              -1.0       1892.5964
# 27                     4.34              10.0      32879.4880
# 28                     5.92               9.0      16414.0780
# 29                      NaN               NaN       4239.6982
#
#     happiness_index  freedom_index  less_corruption_index  \
# 0             5.140        0.51697                0.02781
# 1             4.565        0.39786                0.08492
# 2             7.119        0.54604                0.15890
# 3             5.399        0.46611                0.00000
# 4             5.194        0.12102                0.10464
# 5             6.983        0.49049                0.17521
# 6             5.268        0.34334                0.04030
# 7             4.694        0.40820                0.12569
# 8             5.716        0.36679                0.03005
# 9             7.187        0.48181                0.21312
# 10            5.987        0.49615                0.18060
# 11            4.512        0.43450                0.15048
# 12            5.073        0.62545                0.12279
# 13            4.194        0.17288                0.06324
# 14            5.360        0.59444                0.10441
# 15            5.332        0.22815                0.15746
# 16            4.686        0.30033                0.05863
# 17            6.750        0.61477                0.21843
# 18            6.455        0.55664                0.03187
# 19            6.867        0.59625                0.32067
# 20            6.575        0.55011                0.20646
# 21            3.781        0.32878                0.05747
# 22            5.948        0.26236                0.02901
# 23            4.642        0.33207                0.08884
# 24            4.419        0.42215                0.05839
# 25            6.477        0.53466                0.05120
# 26            3.931        0.45727                0.07267
# 27            6.329        0.45951                0.06398
# 28            6.574        0.44974                0.08484
# 29            4.550        0.10081                0.14660
#
#     life_expectancy_years  inequality_gini  median_household_income_dollars  \
# 0                  75.928             38.5                           6180.0
# 1                  68.607             35.7                           3168.0
# 2                  78.910             41.1                          43585.0
# 3                  70.768             37.8                           2199.0
# 4                  66.577             33.5                           4060.0
# 5                  74.994             53.9                           7522.0
# 6                  53.112             35.1                           2667.0
# 7                  71.514             32.4                           2819.0
# 8                  71.464             37.5                          11724.0
# 9                  74.904             36.8                          11680.0
# 10                 83.879             32.9                          33822.0
# 11                 65.048             35.0                              NaN
# 12                 70.644             44.4                           2401.0
# 13                 71.302             31.5                           3111.0
# 14                 75.110             35.7                           4783.0
# 15                 76.532             41.9                           8955.0
# 16                 75.796             40.8                          12046.0
# 17                 80.770             31.9                          33333.0
# 18                 76.091             36.4                           7029.0
# 19                 81.052             34.8                          31617.0
# 20                 82.224             31.6                          31112.0
# 21                 63.111             40.5                           2154.0
# 22                 82.828             35.9                          20085.0
# 23                 62.649             63.0                           5217.0
# 24                 64.798             40.8                           1870.0
# 25                 76.531             50.4                           6544.0
# 26                 61.373             42.8                           1775.0
# 27                 82.981             34.7                          21959.0
# 28                 76.068             41.4                          14432.0
# 29                 64.429             34.2                           3640.0
#
#     median_per_capita_income_dollars  median_individual_income_dollars
# 0                             1786.0                           10410.0
# 1                              616.0                            2130.0
# 2                            15480.0                           65760.0
# 3                              541.0                            4050.0
# 4                              480.0                            1530.0
# 5                             2247.0                            9130.0
# 6                              493.0                            2030.0
# 7                              567.0                            1940.0
# 8                             4129.0                           11260.0
# 9                             2900.0                            9430.0
# 10                           10840.0                           41690.0
# 11                               NaN                             850.0
# 12                             478.0                            3850.0
# 13                             623.0                            2690.0
# 14                            1124.0                            2540.0
# 15                            2538.0                            9610.0
# 16                            3115.0                            5420.0
# 17                           14098.0                           48520.0
# 18                            1795.0                            7260.0
# 19                           12399.0                           42370.0
# 20                           12445.0                           42400.0
# 21                             384.0                               NaN
# 22                            6874.0                           34460.0
# 23                            1217.0                            6040.0
# 24                             402.0                            1750.0
# 25                            1534.0                            6510.0
# 26                             296.0                               NaN
# 27                            7284.0                           30390.0
# 28                            4109.0                           11200.0
# 29                             579.0                             590.0

# %% [markdown]
# ## Data overview
# Check for overviews of the data before imputing

# %%
gov.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 126 entries, 0 to 125
# Data columns (total 15 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   country                           126 non-null    object
#  1   population                        126 non-null    float64
#  2   area_square_km                    126 non-null    int64
#  3   density_square_km                 126 non-null    float64
#  4   average_years_of_school           109 non-null    float64
#  5   auto_demo_polity                  120 non-null    float64
#  6   gdp_per_capita                    125 non-null    float64
#  7   happiness_index                   126 non-null    float64
#  8   freedom_index                     126 non-null    float64
#  9   less_corruption_index             126 non-null    float64
#  10  life_expectancy_years             126 non-null    float64
#  11  inequality_gini                   126 non-null    float64
#  12  median_household_income_dollars   122 non-null    float64
#  13  median_per_capita_income_dollars  122 non-null    float64
#  14  median_individual_income_dollars  70 non-null     float64
# dtypes: float64(13), int64(1), object(1)
# memory usage: 15.8+ KB

# %%
gov.isnull().sum() #missing values for gdp, school, and auto_demo
# Out:
# country                              0
# population                           0
# area_square_km                       0
# density_square_km                    0
# average_years_of_school             17
# auto_demo_polity                     6
# gdp_per_capita                       1
# happiness_index                      0
# freedom_index                        0
# less_corruption_index                0
# life_expectancy_years                0
# inequality_gini                      0
# median_household_income_dollars      4
# median_per_capita_income_dollars     4
# median_individual_income_dollars    56
# dtype: int64

# %%
gov.isnull().sum().sum()
# Out:
# 88

# %%
gov.describe()
# Out:
#          population  area_square_km  density_square_km  \
# count  1.260000e+02    1.260000e+02         126.000000
# mean   5.831055e+04    9.549778e+05         260.975326
# std    1.821544e+05    2.314626e+06         957.051078
# min    3.433530e+02    3.160000e+02           2.128600
# 25%    6.545963e+03    6.537750e+04          33.742425
# 50%    1.509575e+04    2.384620e+05          90.919250
# 75%    4.289495e+04    7.766970e+05         149.173675
# max    1.444216e+06    1.709824e+07        8305.191500
#
#        average_years_of_school  auto_demo_polity  gdp_per_capita  \
# count               109.000000        120.000000      125.000000
# mean                  3.966697          5.233333    19115.074617
# std                   2.724557          5.623679    18464.330398
# min                   0.010000        -10.000000      781.909550
# 25%                   1.450000          2.750000     4965.561000
# 50%                   3.380000          7.500000    13594.711000
# 75%                   5.790000         10.000000    25939.902000
# max                  10.690000         10.000000    98941.203000
#
#        happiness_index  freedom_index  less_corruption_index  \
# count       126.000000     126.000000             126.000000
# mean          5.450905       0.430080               0.142531
# std           1.177540       0.157006               0.124552
# min           2.839000       0.000000               0.000000
# 25%           4.566500       0.328330               0.059275
# 50%           5.277000       0.434635               0.104525
# 75%           6.444000       0.556168               0.175060
# max           7.587000       0.669730               0.551910
#
#        life_expectancy_years  inequality_gini  \
# count             126.000000       126.000000
# mean               73.123786        37.319841
# std                 7.594370         7.328203
# min                52.941000        24.200000
# 25%                68.614500        32.700000
# 50%                74.913500        35.950000
# 75%                79.401250        41.325000
# max                84.043000        63.000000
#
#        median_household_income_dollars  median_per_capita_income_dollars  \
# count                       122.000000                        122.000000
# mean                      12599.934426                       3896.540984
# std                       12865.220644                       4820.751979
# min                         571.000000                         47.000000
# 25%                        3551.250000                        616.250000
# 50%                        7437.500000                       1790.500000
# 75%                       16219.750000                       5095.500000
# max                       52493.000000                      19308.000000
#
#        median_individual_income_dollars
# count                         70.000000
# mean                       24107.142857
# std                        24240.146849
# min                          540.000000
# 25%                         4347.500000
# 50%                        11480.000000
# 75%                        43425.000000
# max                        85500.000000

# %% [markdown]
# ## Impute Missing Data and Export
# I will just impute with the median given how there are only 88 missing values in the whole dataset, if there were more I might experiment with more advanced imputation methods

# %%
gov['average_years_of_school'] = gov['average_years_of_school'].fillna(gov['average_years_of_school'].dropna().median())
gov['auto_demo_polity'] = gov['auto_demo_polity'].fillna(gov['auto_demo_polity'].dropna().median())
gov['gdp_per_capita'] = gov['gdp_per_capita'].fillna(gov['gdp_per_capita'].dropna().median())
gov['median_household_income_dollars'] = gov['median_household_income_dollars'].fillna(gov['median_household_income_dollars'].dropna().median())
gov['median_per_capita_income_dollars'] = gov['median_per_capita_income_dollars'].fillna(gov['median_per_capita_income_dollars'].dropna().median())
gov['median_individual_income_dollars'] = gov['median_individual_income_dollars'].fillna(gov['median_individual_income_dollars'].dropna().median())

gov.isnull().sum().sum()
# Out:
# 0

# %%
gov.to_csv('gov.csv', index = False)
